# %% [markdown]
# # Calculate Size of Primitive Data Types

# %%
import sys

def show_sizeof(x, level=0):

    print("\t" * level, x.__class__, sys.getsizeof(x), x)

    if hasattr(x, '__iter__'):
        if hasattr(x, 'items'):
            for xx in x.items():
                show_sizeof(xx, level + 1)
        else:
            for xx in x:
                show_sizeof(xx, level + 1)

# %%
show_sizeof(3)
show_sizeof(3.1)
show_sizeof(True)
show_sizeof([])
show_sizeof({})
show_sizeof(())
# Out:
#  <class 'int'> 28 3
#  <class 'float'> 24 3.1
#  <class 'bool'> 28 True
#  <class 'list'> 64 []
#  <class 'dict'> 240 {}
#  <class 'tuple'> 48 ()

# %% [markdown]
# # Take multiple inputs on the same line

# %%
x = [int(i) for i in input().split()]
print(x)
print(type(x))
# Out:
# 8 8 8 8 8
# [8, 8, 8, 8, 8]
# <class 'list'>

# %%
x = list(map(int, input().split()))
print(x)
print(type(x))
# Out:
# 1 2 3
# [1, 2, 3]
# <class 'list'>

# %% [markdown]
# # Take Input as a Matrix (2D List)

# %%
N = int(input())
matrix = []
for row in range(N):
    matrix.append([])
    matrix[row] = list(map(int, input().split()))
print(matrix)
# Out:
# 2
# 1 2
# 1 2
# [[1, 2], [1, 2]]

# %% [markdown]
# # Tanspose a  Matrix (2D List)

# %%
import numpy as np

matrix = [[1, 2], [3, 4], [5, 6]]
transpose_matrix = np.array(matrix).T.tolist()
print(matrix, "\n", transpose_matrix)
# Out:
# [[1, 2], [3, 4], [5, 6]]
#  [[1, 3, 5], [2, 4, 6]]

# %%
matrix = [[1, 2], [3, 4], [5, 6]]
transpose_matrix = [[matrix[j][i] for j in range(len(matrix))] for i in range(len(matrix[0]))]
print(matrix, "\n", transpose_matrix)
# Out:
# [[1, 2], [3, 4], [5, 6]]
#  [[1, 3, 5], [2, 4, 6]]

# %% [markdown]
# # Calculate runtime

# %%
from timeit import timeit

code_to_test = """
a = range(100000)
b = []
for i in a:
    b.append(i*2)
"""

elapsed_time = timeit(code_to_test, number=100)/100
print(elapsed_time)
# Out:
# 0.010733751000007032

# %% [markdown]
# # Get around for loop iterator unchanging value
# #### SUMMER OF '69: Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extending to the next 9 (every 6 will be followed by at least one 9). Return 0 for no numbers.
#
#     summer_69([1, 3, 5]) --> 9
#     summer_69([4, 5, 6, 7, 8, 9]) --> 9
#     summer_69([2, 1, 6, 9, 11]) --> 14

# %%
def summer_69(arr):
    total = 0
    add = True
    for num in arr:
        while add:
            if num != 6:
                total += num
                break
            else:
                add = False
        while not add:
            if num != 9:
                break
            else:
                add = True
                break
    print(total)

# Check
summer_69([1, 3, 5])

# Check
summer_69([4, 5, 6, 7, 8, 9])

# Check
summer_69([2, 1, 6, 9, 11])
# Out:
# 9
# 9
# 14

# %% [markdown]
# # Insertion Sort

# %%
def swap(current, after):
    if columns[after] < columns[current]:
        columns[current], columns[after] = columns[after], columns[current]
    else:
        pass

    if current != 0:
        swap(current-1, after-1)
    
n = int(input())

columns = []
columns.extend(list(map(int, input().split())))

for i in range(n-1):
    swap(i, i+1)

for i in range(n):
    print(columns[i], end=" ")

# %% [markdown]
# # Joining Lists

# %%
test = [['I', 'L'], ['O', 'V'], 'E', 'G', 'F', 'G']
print(test, len(test))

test[0][0:2] = [''.join(test[0][0:2])]
test[1][0:2] = [''.join(test[1][0:2])]
print(test, len(test))

test[0] = "".join(test[0])
test[1] = "".join(test[1])
print(test, len(test))

test[0:2] = [''.join(test[0:2])]
print(test, len(test))
# Out:
# [['I', 'L'], ['O', 'V'], 'E', 'G', 'F', 'G'] 6
# [['IL'], ['OV'], 'E', 'G', 'F', 'G'] 6
# ['IL', 'OV', 'E', 'G', 'F', 'G'] 6
# ['ILOV', 'E', 'G', 'F', 'G'] 5

# %% [markdown]
# # Append() vs Extend()
# append adds its argument as a single element to the end of a list. The length of the list itself will increase by one. extend iterates over its argument adding each element to the list, extending the list. The length of the list will increase by however many elements were in the iterable argument.

# %% [markdown]
# # Upper() vs Capitalize()
# upper takes no arguments and capitalizes all the characters of the string, while capitalize takes an argument of the string which you wish to capitalize only it's first character.

# %% [markdown]
# # Lexicographical Order
# Lexicographic order is the way of ordering of words based on the alphabetical order of their component letters.

# %%
from IPython.core.display import HTML
HTML("""
<style>

#notebook-container {
    box-shadow: none !important;
    background: #000;
}

.cm-s-ipython div.CodeMirror-cursor {
    border: none;
    width: 0.1em;
    background-color: rgba(255, 255, 255, 0.3);
}
    
.container {
    width: 90% !important;
}

.cm-s-ipython span.cm-def {
    color: #f10606;
}

.cm-s-ipython, span.cm-variable, .cm-s-ipython span.cm-variable {
    color: #FFF;
}

.prompt_container {
    background: #1C1C1C;
    border-style: solid;
    border-width: 0.25em;
    border-color: #000 #404040 #000 #000;
}

.filename, .autosave_status, .checkpoint_status {
    color: #FFF;
}

.notebook_app {
    background: #404040 !important;
}

body > #header {
    background:  #1C1C1C;
    height: 17%;
}

.navbar-default {
    background: none;
    border: none;
}

.navbar-default .navbar-nav > li > a, #kernel_indicator {
    color: rgb(255, 255, 255);
    border-bottom: 3px solid #407DAE;
    transition: all 0.25s;
}

.navbar-default .navbar-nav > li > a:hover, #kernel_indicator:hover {
    border-bottom: 2px solid #fff;
    color: rgba(255, 255, 255, 0.75);
}

div.input_area {
    border: none;
    border-radius: 0;
    background: #1C1C1C;
    line-height: 1.5em;
    margin: 0.5em 0;
    padding: 0;
}

div.cell {
    transition: all 0.25s;
    border: none;
    position: relative;
    top: 0;
}


div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border: none;
    background: transparent;
    box-shadow: 4px 4px 12px #aaa;
    z-index: 10;
    top: -10px;
}

div#pager {
    opacity: 0.85;
    z-index: 9999;
}

.navbar-default .navbar-nav > .open > a, .navbar-default .navbar-nav > .open > a:hover, .navbar-default .navbar-nav > .open > a:focus {
    color: #fff;
    background-color: transparent;
    border-bottom: 2px solid #FFF;
}

.dropdown-menu {
    z-index: 999999 !important;
    background-color: #404040;
    opacity: 0.98;
}

.dropdown-menu > li > a {
    color: #FFF;
}

.dropdown-menu > .disabled > a, .dropdown-menu > .disabled > a:hover, .dropdown-menu > .disabled > a:focus {
    color: rgba(255, 255, 255, 0.1);
}

.navbar-nav > li > .dropdown-menu {
    border: none;
    box-shadow: none;
}

div.output_wrapper {
    background: #FFF;
}

div.cell.unselected div.output_area {
    box-shadow: inset 0 0 0 0;
    padding: 1em 0;
    overflow-x: auto;
    transition: all 0.25s;
}

div.cell.selected .output_area {
    box-shadow: inset 0 0 5px #aaa;
    padding: 0.5em 0;
    overflow-x: auto;
}

.edit_mode div.cell.selected:before {
    background: #407DAE;
}

div.cell.selected:before {
    background: #404040;
}

div.cell.selected .div.output_scroll {
    box-shadow: none;
}

div.output_wrapper {
    margin: 0 0 1em;
    transition: all 0.25s;
}

div.cell.selected .output_wrapper {
    margin: 0;
}

.output {
    background: #000;
}

div.output_area pre {
    color: #FFF;
}

input.raw_input {
    color: #000;
}

.dataframe {
    background: #fff;
    box-shadow: 0px 1px 2px #bbb;
}

.dataframe thead th, .dataframe tbody td {
    text-align: right;
    padding: 1em;
}

.output, div.output_scroll {
    box-shadow: none;
}

.CodeMirror-wrap pre.CodeMirror-line, .CodeMirror-wrap pre.CodeMirror-line-like {
    color: #FFF;
}

.rendered_html pre code {
    background: #000;
    border: 1px solid #ddd;
    border-left: 3px solid #2a7bbd;
    color: #FFF;
    page-break-inside: avoid;
    font-family: monospace;
    font-size: 15px;
    line-height: 1.6;
    max-width: 100%;
    overflow: auto;
    padding: 1em 1.5em;
    display: block;
    word-wrap: break-word;
}

h1, .h1 {
    font-size: 33px;
    font-family: "Trebuchet MS";
    font-size: 2.5em !important;
    color: #2a7bbd;
}

</style>
""")
# Out:
# <style>
#
# #notebook-container {
#     box-shadow: none !important;
#     background: #000;
# }
#
# .cm-s-ipython div.CodeMirror-cursor {
#     border: none;
#     width: 0.1em;
#     background-color: rgba(255, 255, 255, 0.3);
# }
#
# .container {
#     width: 90% !important;
# }
#
# .cm-s-ipython span.cm-def {
#     color: #f10606;
# }
#
# .cm-s-ipython, span.cm-variable, .cm-s-ipython span.cm-variable {
#     color: #FFF;
# }
#
# .prompt_container {
#     background: #1C1C1C;
#     border-style: solid;
#     border-width: 0.25em;
#     border-color: #000 #404040 #000 #000;
# }
#
# .filename, .autosave_status, .checkpoint_status {
#     color: #FFF;
# }
#
# .notebook_app {
#     background: #404040 !important;
# }
#
# body > #header {
#     background:  #1C1C1C;
#     height: 17%;
# }
#
# .navbar-default {
#     background: none;
#     border: none;
# }
#
# .navbar-default .navbar-nav > li > a, #kernel_indicator {
#     color: rgb(255, 255, 255);
# ...
